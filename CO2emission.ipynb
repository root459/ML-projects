# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# Visualizations:
#
# Engine Size Distribution:
#
# Visualize the distribution of engine sizes (Engine_Size) to see which sizes are most common among the vehicles in the dataset.
# Fuel Consumption:
#
# Create histograms or box plots to visualize the distribution of fuel consumption in the city (Fuel_Consumption_in_City(L/100 km)) and on the highway (Fuel_Consumption_in_City_Hwy(L/100 km)).
# Visualize the relationship between engine size and fuel consumption to see if there is a correlation.
# CO2 Emissions:
#
# Visualize the distribution of CO2 emissions (CO2_Emissions) to understand the environmental impact of the vehicles in the dataset.
# Vehicle Classes:
#
# Create a bar chart to visualize the distribution of vehicles across different classes (Vehicle_Class).
# Transmission Types:
#
# Visualize the distribution of vehicles with different transmission types (Transmission) to see which is most common.
# Smog Level:
#
# Create a bar chart or pie chart to visualize the distribution of vehicles by smog level (Smog_Level).
# Yearly Trends:
#
# If you have data for multiple years, create time series visualizations to show trends in fuel consumption, CO2 emissions, or engine size over the years.
# Predictions:
#
# Fuel Efficiency Prediction:
#
# You can build a regression model to predict fuel consumption in the city, on the highway, and the combined value based on attributes like engine size, cylinders, and transmission type.
# CO2 Emissions Prediction:
#
# Build a regression model to predict CO2 emissions based on attributes like engine size and fuel consumption.
# Smog Level Prediction:
#
# If there's a way to convert the "Smog_Level" into a numeric value, you can build a classification or regression model to predict smog levels based on other attributes.
# Vehicle Class Prediction:
#
# Use other vehicle attributes to predict the vehicle class.
# Make and Model Recommendations:
#
# If you have data for multiple years, you can build recommendation systems that suggest vehicle makes and models based on a user's preferences for attributes like fuel consumption or engine size.
# Trends and Anomalies:
#
# Use time series analysis to identify trends and anomalies in fuel consumption, CO2 emissions, or other attributes over time.

# %%
df=pd.read_csv("./data/CO2_emission.csv")
df
# Out:
#      Model_Year   Make              Model  Vehicle_Class  Engine_Size  \
# 0          2021  Acura                ILX        Compact          2.4
# 1          2021  Acura                NSX     Two-seater          3.5
# 2          2021  Acura         RDX SH-AWD     SUV: Small          2.0
# 3          2021  Acura  RDX SH-AWD A-SPEC     SUV: Small          2.0
# 4          2021  Acura         TLX SH-AWD        Compact          2.0
# ..          ...    ...                ...            ...          ...
# 930        2021  Volvo        XC40 T5 AWD     SUV: Small          2.0
# 931        2021  Volvo        XC60 T5 AWD     SUV: Small          2.0
# 932        2021  Volvo        XC60 T6 AWD     SUV: Small          2.0
# 933        2021  Volvo        XC90 T5 AWD  SUV: Standard          2.0
# 934        2021  Volvo        XC90 T6 AWD  SUV: Standard          2.0
#
#      Cylinders Transmission  Fuel_Consumption_in_City(L/100 km)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 12 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Model_Year                              935 non-null    int64
#  1   Make                                    935 non-null    object
#  2   Model                                   935 non-null    object
#  3   Vehicle_Class                           935 non-null    object
#  4   Engine_Size                             935 non-null    float64
#  5   Cylinders                               935 non-null    int64
#  6   Transmission                            935 non-null    object
#  7   Fuel_Consumption_in_City(L/100 km)      935 non-null    float64
#  8   Fuel_Consumption_in_City_Hwy(L/100 km)  935 non-null    float64
#  9   Fuel_Consumption_comb(L/100km)          935 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Model_Year  Engine_Size   Cylinders  \
# count       935.0   935.000000  935.000000
# mean       2021.0     3.214866    5.716578
# std           0.0     1.388513    1.977359
# min        2021.0     1.000000    3.000000
# 25%        2021.0     2.000000    4.000000
# 50%        2021.0     3.000000    6.000000
# 75%        2021.0     4.000000    8.000000
# max        2021.0     8.000000   16.000000
#
#        Fuel_Consumption_in_City(L/100 km)  \
# count                          935.000000
# mean                            12.498610
# std                              3.487271
# min                              4.000000
# 25%                             10.100000
# 50%                             12.000000
# 75%                             14.800000
# max                             30.300000
#
#        Fuel_Consumption_in_City_Hwy(L/100 km)  Fuel_Consumption_comb(L/100km)  \
# count                              935.000000                      935.000000
# ...

# %%
df.isnull().sum()
# Out:
# Model_Year                                0
# Make                                      0
# Model                                     0
# Vehicle_Class                             0
# Engine_Size                               0
# Cylinders                                 0
# Transmission                              0
# Fuel_Consumption_in_City(L/100 km)        0
# Fuel_Consumption_in_City_Hwy(L/100 km)    0
# Fuel_Consumption_comb(L/100km)            0
# CO2_Emissions                             0
# Smog_Level                                0
# dtype: int64

# %% [raw]
# So there is no null values in this dataset.

# %%
fig = plt.figure(figsize = (15,15))
ax = fig.gca()
g = df.hist(ax=ax)
# Out:
# C:\Users\Yuvraj Singh Rathore\AppData\Local\Temp\ipykernel_2008\3980286831.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   g = df.hist(ax=ax)

# %%
plt.figure(figsize=(10, 6))  # Set the figure size

# Use Seaborn to create a histogram
sns.histplot(data=df, x='Engine_Size', bins=20, kde=True)

plt.title('Distribution of Engine Sizes')
plt.xlabel('Engine Size')
plt.ylabel('Frequency')

plt.show()
